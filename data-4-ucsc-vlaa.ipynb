# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("UCSC-VLAA/MedReason")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# ours_quality_33000.jsonl:   0%|          | 0.00/115M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/32682 [00:00<?, ? examples/s]

# %%
print(ds)  # 会显示 'train'、'validation' 等子集
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['dataset_name', 'id_in_dataset', 'question', 'answer', 'reasoning', 'options'],
#         num_rows: 32682
#     })
# })

# %%
# 展示训练集的前3条样本
for i in range(3):
    print(f"\n=== Sample {i+1} ===")
    print(ds['train'][i])
# Out:
# === Sample 1 ===
# {'dataset_name': 'medmcqa', 'id_in_dataset': 7131, 'question': 'Urogenital Diaphragm is made up of the following, except:', 'answer': "Colle's fascia. Explanation: Colle's fascia does not contribute to the Urogenital Diaphragm. It is attached posteriorly to the posterior border of the urogenital diaphragm but does not form pa of this diaphragm. Ref: BDC, Volume 2, 4th Edition, Page 332; Grants Method of Anatomy, 11th Edition, Page 244; Gray's Anatomy, 36th Edition, Page 563", 'reasoning': "Finding reasoning paths:\n1. Urogenital diaphragm -> Pelvic anatomy -> Muscles and fascia -> Deep perineal pouch\n2. Urogenital diaphragm -> Components of the perineum -> Muscles and connective tissue\n3. Urogenital diaphragm -> Anatomical structures -> Superficial vs. deep fascia\n\nReasoning Process:\n1. The urogenital diaphragm is a structure located in the pelvic region, specifically within the perineum. It is important to understand its composition to determine which structures contribute to its formation.\n\n2. The urogenital diaphragm is primarily composed of the deep transverse perineal muscle and the perineal membrane. These structures are located in the deep perineal pouch, which is a part of the pelvic floor.\n\n3. The perineal membrane is a layer of fascia that provides support and is part of the urogenital diaphragm. It is important to distinguish between the deep fascia, which contributes to the diaphragm, and the superficial fascia, which does not.\n\n4. Colle's fascia is a type of superficial fascia found in the perineal region. It is continuous with the superficial fascia of the abdominal wall and is located more superficially than the structures forming the urogenital diaphragm.\n\n5. Since the urogenital diaphragm is composed of deeper structures, such as the deep transverse perineal muscle and the perineal membrane, superficial fascia like Colle's fascia does not contribute to its formation.\n\nConclusion:\nColle's fascia, being a type of superficial fascia, does not contribute to the formation of the urogenital diaphragm.", 'options': "Answer Choices:\nA. Deep transverse Perineus\nB. Perinial membrane\nC. Colle's fascia\nD. Sphincter Urethrae"}
#
# === Sample 2 ===
# {'dataset_name': 'medmcqa', 'id_in_dataset': 7133, 'question': 'Child with Type I Diabetes. What is the advised time for fundus examinations from the time of diagnosis?', 'answer': 'After 5 years. Explanation: Screening for diabetic retinopathy To prevent visual loss occurring from diabetic retinopathy a periodic follow-up is very impoant for a timely intervention. The recommendations for periodic fundus examination are as follows : First examination, 5 years after diagnosis of type 1 DM and at the time of diagnosis in type 2 DM. Every year, till there is no diabetic retinopathy or there is mild NPDR. Every 6 months, in moderate NPDR. Every 3 months, in severe NPDR Every 2 months, in PDR with no high-risk characteristics. Ref;A.K.Khurana; 6th edition; Page no: 280', 'reasoning': '**Finding reasoning paths:**\n\n1. Type 1 Diabetes Mellitus -> Risk of Diabetic Retinopathy -> Timing of Fundus Examination\n2. Type 1 Diabetes Mellitus -> Duration of Diabetes -> Risk of Retinopathy -> Fundus Examination Guidelines\n3. Type 1 Diabetes Mellitus -> Pediatric Guidelines -> Fundus Examination Timing\n\n**Reasoning Process:**\n\n1. **Understanding Diabetic Retinopathy:** Diabetic retinopathy is a complication of diabetes that affects the eyes. It is caused by damage to the blood vessels of the light-sensitive tissue at the back of the eye (retina). Monitoring for diabetic retinopathy is crucial to prevent visual loss.\n\n2. **Type 1 Diabetes Mellitus and Retinopathy Risk:** In Type 1 Diabetes Mellitus, the risk of developing diabetic retinopathy is related to the duration of diabetes. The longer a person has diabetes, the higher the risk of developing retinopathy.\n\n3. **Guidelines for Fundus Examination in Type 1 Diabetes:** According to established medical guidelines, children with Type 1 Diabetes should have their first fundus examination 5 years after the diagnosis of diabetes. This is because significant retinopathy is unlikely to develop before this time frame in children.\n\n4. **Comparison with Type 2 Diabetes Mellitus:** In contrast, individuals with Type 2 Diabetes Mellitus are often diagnosed later in life and may have had undiagnosed diabetes for some time. Therefore, the recommendation is to have a fundus examination at the time of diagnosis to assess any existing retinopathy.\n\n5. **Pediatric Considerations:** For children with Type 1 Diabetes, the focus is on monitoring and preventing complications as they grow. The timing of the first fundus examination is aligned with the expected onset of retinopathy risk.\n\n**Conclusion:**\n\nThe advised time for the first fundus examination in a child with Type 1 Diabetes Mellitus is 5 years after the diagnosis. This timing is based on the understanding that the risk of developing significant diabetic retinopathy increases with the duration of diabetes, and early screening helps in timely intervention.', 'options': 'Answer Choices:\nA. After 5 years\nB. After 2 years\nC. After 10 years\nD. At the time of diagnosis'}
#
# === Sample 3 ===
# {'dataset_name': 'medmcqa', 'id_in_dataset': 7134, 'question': 'Most sensitive test for H pylori is-', 'answer': 'Biopsy urease test. Explanation: <P>Davidson&;s principles and practice of medicine 22nd edition. *biopsbiopsy unease test is cheap,quick ,specific(95%) and sensitivity (85%)</p>', 'reasoning': '**Finding reasoning paths:**\n\n1. Consider the various diagnostic tests available for Helicobacter pylori infection, such as the urea breath test, stool antigen test, serology, and biopsy-based methods.\n2. Evaluate the sensitivity and specificity of each test.\n3. Consider the invasiveness and practicality of each test in clinical settings.\n4. Review current clinical guidelines and research studies on the detection of Helicobacter pylori.\n\n**Reasoning Process:**\n\n1. **Diagnostic Tests Overview:**\n   - Helicobacter pylori infection can be diagnosed using non-invasive tests like the urea breath test and stool antigen test, as well as invasive methods like endoscopic biopsy with histology, culture, or urease testing.\n\n2. **Sensitivity and Specificity:**\n   - The urea breath test is known for its high sensitivity and specificity, often considered the gold standard among non-invasive tests.\n   - The stool antigen test is also highly sensitive and specific, particularly useful for post-treatment monitoring.\n   - Serology is less sensitive and specific because it cannot distinguish between active and past infections.\n   - Biopsy-based methods, including the biopsy urease test, histology, and culture, are highly sensitive and specific but require endoscopy.\n\n3. **Invasiveness and Practicality:**\n   - Non-invasive tests like the urea breath test and stool antigen test are preferred for initial diagnosis due to their ease of use and patient comfort.\n   - Biopsy-based methods, while invasive, provide direct evidence of infection and allow for additional testing, such as antibiotic susceptibility.\n\n4. **Clinical Guidelines and Research:**\n   - Current guidelines often recommend the urea breath test or stool antigen test for initial diagnosis due to their non-invasive nature and high accuracy.\n   - Biopsy urease tests are highly sensitive and specific but are typically used when endoscopy is already indicated for other reasons.\n\n**Conclusion:**\n\nBased on the reasoning process, the urea breath test is often considered the most sensitive and practical test for detecting Helicobacter pylori infection in a non-invasive manner. However, the biopsy urease test is highly sensitive and specific when endoscopy is performed. Therefore, while the biopsy urease test is very sensitive, the urea breath test is generally preferred for its non-invasive nature and high sensitivity in initial testing scenarios.', 'options': 'Answer Choices:\nA. Fecal antigen test\nB. Biopsy urease test\nC. Serological test\nD. Urea breath test'}

# %%
train_dataset = ds['train']

# 提取数据
extracted_data = []

for entry in train_dataset:
    options = entry.get('options', '')

    # 初始化选项字典
    parsed_options = {'A': '', 'B': '', 'C': '', 'D': ''}

    # 解析字符串形式的选项（如 "Answer Choices:\nA. xxx\nB. yyy..."）
    for line in options.split('\n'):
        line = line.strip()
        if '.' in line and line[0] in ['A', 'B', 'C', 'D']:
            key = line[0]
            value = line[2:].strip()
            parsed_options[key] = value

    # 构建新条目
    new_entry = {
        'question': entry.get('question', ''),
        'A': parsed_options.get('A', ''),
        'B': parsed_options.get('B', ''),
        'C': parsed_options.get('C', ''),
        'D': parsed_options.get('D', ''),
        'answer': entry.get('answer', ''),
        'exp': entry.get('reasoning', '')
    }

    extracted_data.append(new_entry)

# 归一化答案：将文本形式的答案转为 A/B/C/D
def normalize_answer(entry):
    correct_ans_text = entry.get('answer', '').split('.')[0].strip()  # 提取答案前的关键词
    for key in ['A', 'B', 'C', 'D']:
        option_value = entry.get(key)
        if option_value and correct_ans_text.lower() == option_value.lower():
            return key
    return "Unknown"

# 应用归一化
for item in extracted_data:
    item['answer'] = normalize_answer(item)

# 打印前5个样本查看效果
for i, item in enumerate(extracted_data[:5], 1):
    print(f"\n=== Entry {i} ===")
    for key in ['question', 'A', 'B', 'C', 'D', 'answer', 'exp']:
        print(f"{key}: {item.get(key)}")
# Out:
# === Entry 1 ===
# question: Urogenital Diaphragm is made up of the following, except:
# A: Deep transverse Perineus
# B: Perinial membrane
# C: Colle's fascia
# D: Sphincter Urethrae
# answer: C
# exp: Finding reasoning paths:
# 1. Urogenital diaphragm -> Pelvic anatomy -> Muscles and fascia -> Deep perineal pouch
# 2. Urogenital diaphragm -> Components of the perineum -> Muscles and connective tissue
# 3. Urogenital diaphragm -> Anatomical structures -> Superficial vs. deep fascia
#
# Reasoning Process:
# 1. The urogenital diaphragm is a structure located in the pelvic region, specifically within the perineum. It is important to understand its composition to determine which structures contribute to its formation.
#
# 2. The urogenital diaphragm is primarily composed of the deep transverse perineal muscle and the perineal membrane. These structures are located in the deep perineal pouch, which is a part of the pelvic floor.
#
# 3. The perineal membrane is a layer of fascia that provides support and is part of the urogenital diaphragm. It is important to distinguish between the deep fascia, which contributes to the diaphragm, and the superficial fascia, which does not.
#
# 4. Colle's fascia is a type of superficial fascia found in the perineal region. It is continuous with the superficial fascia of the abdominal wall and is located more superficially than the structures forming the urogenital diaphragm.
#
# 5. Since the urogenital diaphragm is composed of deeper structures, such as the deep transverse perineal muscle and the perineal membrane, superficial fascia like Colle's fascia does not contribute to its formation.
#
# Conclusion:
# Colle's fascia, being a type of superficial fascia, does not contribute to the formation of the urogenital diaphragm.
#
# === Entry 2 ===
# question: Child with Type I Diabetes. What is the advised time for fundus examinations from the time of diagnosis?
# A: After 5 years
# B: After 2 years
# C: After 10 years
# D: At the time of diagnosis
# answer: A
# exp: **Finding reasoning paths:**
#
# 1. Type 1 Diabetes Mellitus -> Risk of Diabetic Retinopathy -> Timing of Fundus Examination
# 2. Type 1 Diabetes Mellitus -> Duration of Diabetes -> Risk of Retinopathy -> Fundus Examination Guidelines
# 3. Type 1 Diabetes Mellitus -> Pediatric Guidelines -> Fundus Examination Timing
#
# **Reasoning Process:**
#
# 1. **Understanding Diabetic Retinopathy:** Diabetic retinopathy is a complication of diabetes that affects the eyes. It is caused by damage to the blood vessels of the light-sensitive tissue at the back of the eye (retina). Monitoring for diabetic retinopathy is crucial to prevent visual loss.
#
# 2. **Type 1 Diabetes Mellitus and Retinopathy Risk:** In Type 1 Diabetes Mellitus, the risk of developing diabetic retinopathy is related to the duration of diabetes. The longer a person has diabetes, the higher the risk of developing retinopathy.
#
# 3. **Guidelines for Fundus Examination in Type 1 Diabetes:** According to established medical guidelines, children with Type 1 Diabetes should have their first fundus examination 5 years after the diagnosis of diabetes. This is because significant retinopathy is unlikely to develop before this time frame in children.
#
# 4. **Comparison with Type 2 Diabetes Mellitus:** In contrast, individuals with Type 2 Diabetes Mellitus are often diagnosed later in life and may have had undiagnosed diabetes for some time. Therefore, the recommendation is to have a fundus examination at the time of diagnosis to assess any existing retinopathy.
#
# 5. **Pediatric Considerations:** For children with Type 1 Diabetes, the focus is on monitoring and preventing complications as they grow. The timing of the first fundus examination is aligned with the expected onset of retinopathy risk.
#
# **Conclusion:**
#
# The advised time for the first fundus examination in a child with Type 1 Diabetes Mellitus is 5 years after the diagnosis. This timing is based on the understanding that the risk of developing significant diabetic retinopathy increases with the duration of diabetes, and early screening helps in timely intervention.
#
# === Entry 3 ===
# question: Most sensitive test for H pylori is-
# A: Fecal antigen test
# B: Biopsy urease test
# C: Serological test
# D: Urea breath test
# answer: B
# exp: **Finding reasoning paths:**
#
# 1. Consider the various diagnostic tests available for Helicobacter pylori infection, such as the urea breath test, stool antigen test, serology, and biopsy-based methods.
# 2. Evaluate the sensitivity and specificity of each test.
# 3. Consider the invasiveness and practicality of each test in clinical settings.
# 4. Review current clinical guidelines and research studies on the detection of Helicobacter pylori.
#
# **Reasoning Process:**
#
# 1. **Diagnostic Tests Overview:**
#    - Helicobacter pylori infection can be diagnosed using non-invasive tests like the urea breath test and stool antigen test, as well as invasive methods like endoscopic biopsy with histology, culture, or urease testing.
#
# 2. **Sensitivity and Specificity:**
#    - The urea breath test is known for its high sensitivity and specificity, often considered the gold standard among non-invasive tests.
#    - The stool antigen test is also highly sensitive and specific, particularly useful for post-treatment monitoring.
#    - Serology is less sensitive and specific because it cannot distinguish between active and past infections.
#    - Biopsy-based methods, including the biopsy urease test, histology, and culture, are highly sensitive and specific but require endoscopy.
#
# 3. **Invasiveness and Practicality:**
#    - Non-invasive tests like the urea breath test and stool antigen test are preferred for initial diagnosis due to their ease of use and patient comfort.
#    - Biopsy-based methods, while invasive, provide direct evidence of infection and allow for additional testing, such as antibiotic susceptibility.
#
# 4. **Clinical Guidelines and Research:**
#    - Current guidelines often recommend the urea breath test or stool antigen test for initial diagnosis due to their non-invasive nature and high accuracy.
#    - Biopsy urease tests are highly sensitive and specific but are typically used when endoscopy is already indicated for other reasons.
#
# **Conclusion:**
#
# Based on the reasoning process, the urea breath test is often considered the most sensitive and practical test for detecting Helicobacter pylori infection in a non-invasive manner. However, the biopsy urease test is highly sensitive and specific when endoscopy is performed. Therefore, while the biopsy urease test is very sensitive, the urea breath test is generally preferred for its non-invasive nature and high sensitivity in initial testing scenarios.
#
# === Entry 4 ===
# question: Ligation of the common hepatic aery will compromise blood flow in
# A: Right and Left gastric aery
# B: Right gastric and sho gastric aeries
# C: Right gastroepiploic and sho gastric aeries
# D: Right gastric and right gastroepiploic aery
# answer: D
# exp: **Finding reasoning paths:**
#
# 1. Common hepatic artery -> Gastroduodenal artery -> Right gastroepiploic artery
# 2. Common hepatic artery -> Gastroduodenal artery -> Right gastric artery
# 3. Common hepatic artery -> Celiac trunk -> Left gastric artery
# 4. Common hepatic artery -> Splenic artery -> Short gastric arteries
#
# **Reasoning Process:**
#
# 1. **Understanding the anatomy:**
#    - The common hepatic artery is a major branch of the celiac trunk, which supplies blood to the liver, stomach, and other abdominal organs.
#    - The common hepatic artery gives rise to the gastroduodenal artery, which further branches into the right gastroepiploic artery and the right gastric artery.
#
# 2. **Impact of ligation:**
#    - Ligation of the common hepatic artery would directly affect the blood flow through its branches.
#    - The gastroduodenal artery, a branch of the common hepatic artery, would have reduced blood flow, affecting its subsequent branches, including the right gastroepiploic artery and the right gastric artery.
#
# 3. **Assessing the branches:**
#    - The right gastroepiploic artery, which supplies the greater curvature of the stomach, arises from the gastroduodenal artery. Therefore, its blood supply would be compromised.
#    - The right gastric artery, which supplies the lesser curvature of the stomach, also arises from the gastroduodenal artery, and its blood supply would be compromised as well.
#
# 4. **Other arteries:**
#    - The left gastric artery arises directly from the celiac trunk, not the common hepatic artery, so its blood supply would not be directly affected by the ligation of the common hepatic artery.
#    - The short gastric arteries arise from the splenic artery, which is another branch of the celiac trunk, and would not be directly affected by the ligation of the common hepatic artery.
#
# **Conclusion:**
#
# Ligation of the common hepatic artery will compromise the blood flow to the right gastric and right gastroepiploic arteries, as they are branches of the gastroduodenal artery, which arises from the common hepatic artery. The left gastric artery and short gastric arteries will not be directly affected by this ligation.
#
# === Entry 5 ===
# question: Typhoid investigation of choice in 1st week
# A: Blood culture
# B: Widal test
# C: Stool culture
# D: Urine culture
# answer: A
# exp: Finding reasoning paths:
#
# 1. Consider the pathophysiology of typhoid fever and how it affects the body in the first week.
# 2. Evaluate the diagnostic methods available for typhoid fever and their effectiveness in the early stages of the disease.
# 3. Analyze the sensitivity and specificity of blood cultures in detecting Salmonella typhi during the first week of infection.
# 4. Compare blood culture with other diagnostic methods such as serological tests or stool cultures in terms of timing and accuracy.
#
# Reasoning Process:
#
# 1. **Pathophysiology of Typhoid Fever**: Typhoid fever is caused by the bacterium Salmonella typhi. In the early stages of infection, the bacteria enter the bloodstream, leading to bacteremia. This is why blood cultures are often considered in the initial diagnostic approach.
#
# 2. **Diagnostic Methods**: Various methods can be used to diagnose typhoid fever, including blood cultures, serological tests (such as the Widal test), and stool cultures. Each method has its own timing and accuracy considerations.
#
# 3. **Blood Culture Sensitivity and Specificity**: Blood cultures are known to be highly sensitive in the first week of typhoid fever, with a positivity rate of approximately 90%. This high sensitivity makes it a reliable method for early diagnosis when the bacteria are present in the bloodstream.
#
# 4. **Comparison with Other Methods**: Serological tests like the Widal test are less reliable in the first week because they depend on the body's immune response, which may not be fully developed. Stool cultures may not be positive until later in the disease course when the bacteria are shed in the feces.
#
# Conclusion:
#
# Blood culture is the preferred method for diagnosing typhoid fever in the first week due to its high sensitivity and ability to detect the presence of Salmonella typhi in the bloodstream during the early stages of infection.

# %%
# 定义关键词（可根据需要扩展）
keywords =  [
    # 冠心病
    'coronary artery disease', 'CAD', 'angina', 'stable angina', 'unstable angina',
    'myocardial infarction', 'MI', 'heart attack', 'NSTEMI', 'STEMI',
    'acute coronary syndrome', 'ACS', 'ischemic heart disease', 'IHD',

    # 心律失常
    'arrhythmia', 'atrial fibrillation', 'ventricular tachycardia',
    'ventricular fibrillation', 'bundle branch block', 'heart block',

    # 心力衰竭
    'heart failure', 'congestive heart failure', 'CHF',
    'left ventricular dysfunction', 'right heart failure',
    'ejection fraction', 'reduced EF', 'cardiomyopathy',
    'dilated cardiomyopathy', 'hypertrophic cardiomyopathy',

    # 心瓣膜病 / 杂音
    'valvular heart disease', 'aortic stenosis', 'mitral regurgitation',
    'heart murmur', 'valve prolapse', 'bicuspid aortic valve',
    'echocardiogram'
]

# 转小写进行匹配
def is_cardiovascular_related(text):
    if text is None:
        return False
    text = text.lower()
    return any(kw in text for kw in keywords)
    
# 过滤符合条件的记录
cardio_questions = [
    item for item in extracted_data
    if is_cardiovascular_related(item.get('question'))
]

print(f"Found {len(cardio_questions)} cardiovascular-related entries.")
# Out:
# Found 1225 cardiovascular-related entries.

# %%
for i, item in enumerate(cardio_questions[:5], 1):
    print(f"\n=== Cardiovascular Entry {i} ===")
    for key in ['question', 'A', 'B', 'C', 'D', 'answer', 'exp']:
        print(f"{key}: {item.get(key)}")
# Out:
# === Cardiovascular Entry 1 ===
# question: Which of the following drugs is used for the prophylaxis of migraine but not for angina pectoris
# A: Verapamnil
# B: Diltiazem
# C: Flunarizine
# D: Amlodipine
# answer: C
# exp: **Finding reasoning paths:**
#
# 1. Flunarizine -> Calcium channel blocker -> Prophylaxis of migraine
# 2. Flunarizine -> Not used for angina pectoris
# 3. Flunarizine -> Not available in the US or Japan
#
# **Reasoning Process:**
#
# 1. **Flunarizine as a Calcium Channel Blocker:**
#    - Flunarizine is classified as a calcium channel blocker. Calcium channel blockers are known to inhibit the influx of calcium ions through cell membranes, which can help in reducing the frequency and severity of migraines. This mechanism is consistent with its use in the prophylaxis of migraine disorders.
#
# 2. **Use in Migraine Prophylaxis:**
#    - The primary indication for flunarizine is the prevention of migraine headaches. By stabilizing neuronal activity and reducing vasospasm, it helps in preventing the onset of migraines.
#
# 3. **Not Used for Angina Pectoris:**
#    - While some calcium channel blockers are used to treat angina pectoris by improving blood flow to the heart muscle, flunarizine is not typically used for this purpose. Its primary clinical use is in the context of migraine prevention.
#
# 4. **Availability:**
#    - Flunarizine is not available by prescription in the United States or Japan. This could be due to regulatory decisions, lack of approval, or market considerations in these countries.
#
# **Conclusion:**
#
# Flunarizine is used for the prophylaxis of migraine disorders due to its calcium channel blocking activity. It is not used for angina pectoris, and it is not available by prescription in the United States or Japan.
#
# === Cardiovascular Entry 2 ===
# question: Which of the following flipped pattern of LDH is seen in myocardial infarction:
# A: LDH 1>2
# B: LDH 2> 1
# C: LDH 3>4
# D: LDH 5> 4
# answer: A
# exp: Finding reasoning paths:
#
# 1. Blood -> LDH-1 and LDH-2 -> Lactate dehydrogenase activity -> Myocardial infarction
# 2. Blood -> LDH-1 and LDH-2 -> Lactate dehydrogenase activity -> Hemolytic anemia
#
# Reasoning Process:
#
# 1. **Understanding LDH Isoenzymes**: Lactate dehydrogenase (LDH) is an enzyme that exists in different isoenzymes, primarily LDH-1 and LDH-2. In normal conditions, LDH-2 is more prevalent in the blood than LDH-1.
#
# 2. **LDH in Myocardial Infarction**: During a myocardial infarction (heart attack), heart muscle cells are damaged, releasing their contents into the bloodstream. Heart muscle cells are rich in LDH-1, leading to an increase in LDH-1 levels in the blood. This results in a "flipped" pattern where LDH-1 becomes greater than LDH-2, which is a diagnostic marker for myocardial infarction.
#
# 3. **LDH in Hemolytic Anemia**: In hemolytic anemia, there is increased destruction of red blood cells, which also contain LDH. However, the pattern typically involves an increase in LDH-2 rather than LDH-1, as red blood cells have a different isoenzyme distribution compared to heart muscle cells.
#
# 4. **Differentiating Conditions**: The key difference between myocardial infarction and hemolytic anemia in terms of LDH patterns is the predominance of LDH-1 in myocardial infarction versus LDH-2 in hemolytic anemia. This distinction helps in diagnosing myocardial infarction when the flipped pattern is observed.
#
# Conclusion:
#
# The flipped pattern of LDH seen in myocardial infarction is characterized by LDH-1 being greater than LDH-2. This pattern is a result of the release of LDH-1 from damaged heart muscle cells, distinguishing it from conditions like hemolytic anemia, where LDH-2 is more elevated.
#
# === Cardiovascular Entry 3 ===
# question: In a patient with chronic atrial fibrillation with a regular beat of 60/min , the most probable cause is -
# A: Sleep
# B: Digitalis toxicity
# C: Sino nodal block
# D: Hypothyroidism
# answer: B
# exp: **Finding reasoning paths:**
#
# 1. Chronic atrial fibrillation (AF) -> Treatment with Digoxin -> Digitalis toxicity -> Regular beat.
# 2. Chronic atrial fibrillation -> AV node dysfunction -> Regular beat.
# 3. Chronic atrial fibrillation -> Medication side effects -> Regular beat.
#
# **Reasoning Process:**
#
# 1. **Chronic Atrial Fibrillation and Treatment:**
#    - Patients with chronic atrial fibrillation often receive medications to control heart rate and rhythm. Digoxin is a common medication used for rate control in AF.
#    - Digoxin can lead to Digitalis toxicity, especially if the patient has renal impairment or is on interacting medications.
#
# 2. **Digitalis Toxicity:**
#    - Digitalis toxicity can cause various arrhythmias, including regularization of the heart rate due to AV block or junctional rhythms.
#    - A regular beat of 60/min could suggest a junctional rhythm or complete heart block, both of which can be associated with Digitalis toxicity.
#
# 3. **AV Node Dysfunction:**
#    - In patients with AF, if there is an underlying AV node dysfunction, it could lead to a regular ventricular response.
#    - However, this is less common without an external factor like medication influencing the conduction system.
#
# 4. **Medication Side Effects:**
#    - Other medications used in AF, such as beta-blockers or calcium channel blockers, can also cause a regular heart rate by affecting the AV node.
#    - However, these typically do not cause a regular beat of exactly 60/min unless there is a specific dosing or toxicity issue.
#
# **Conclusion:**
#
# The most probable cause of a regular beat of 60/min in a patient with chronic atrial fibrillation is Digitalis toxicity due to the use of Digoxin. This is because Digoxin can cause AV block or junctional rhythms, leading to a regular heart rate.
#
# === Cardiovascular Entry 4 ===
# question: The treatment of acute myocardial infarction includes which of the following-
# A: Aspirin
# B: Heparin
# C: Alteplase
# D: Oral anticoagulants
# answer: A
# exp: Finding reasoning paths:
# 1. Acute myocardial infarction -> Aspirin (acetylsalicylic acid) administration
# 2. Acute myocardial infarction -> Pain relief and prevention of complications
# 3. ST-elevation myocardial infarction -> Reperfusion therapy -> Aspirin administration
# 4. Fibrinolysis -> Myocardial infarction -> Aspirin administration
#
# Reasoning Process:
# 1. **Acute Myocardial Infarction (AMI) and Initial Treatment**: When a patient presents with an acute myocardial infarction, the immediate goal is to restore blood flow to the heart muscle to minimize damage. This involves identifying candidates for reperfusion therapy, which can be achieved through primary percutaneous coronary intervention (PCI) or fibrinolysis. Aspirin is a critical component of initial treatment because it inhibits platelet aggregation, reducing the risk of further clot formation and helping to maintain blood flow.
#
# 2. **Role of Aspirin**: Aspirin, or acetylsalicylic acid, is recommended as an initial treatment for AMI due to its antiplatelet effects. It helps prevent the enlargement of the thrombus (blood clot) that is occluding the coronary artery, thereby reducing the risk of further ischemic events. It is typically administered immediately unless contraindicated by an allergy or intolerance.
#
# 3. **Pain Relief and Prevention of Complications**: In addition to reperfusion therapy, managing pain and preventing complications such as arrhythmias are crucial. Aspirin contributes to these goals by reducing the inflammatory response and stabilizing the coronary plaque.
#
# 4. **ST-Elevation Myocardial Infarction (STEMI) and Reperfusion Therapy**: In cases of STEMI, rapid reperfusion is essential. Aspirin is part of the standard treatment protocol, often administered alongside other medications like heparin or fibrinolytics, depending on the availability of PCI and the patient's condition.
#
# 5. **Fibrinolysis and Aspirin**: If PCI is not available, fibrinolysis is considered. Aspirin is used in conjunction with fibrinolytic agents to enhance the overall effectiveness of the treatment by preventing new clot formation.
#
# Conclusion:
# Aspirin is recommended as an initial treatment for acute myocardial infarction to prevent further clot formation and reduce complications. It is a key component of the therapeutic strategy for managing AMI, particularly in the context of reperfusion therapy.
#
# === Cardiovascular Entry 5 ===
# question: Which one of the following congenital heart diseases has cyanosis without cardiomegaly and/or congestive heart failure –
# A: Transposition of great arteries
# B: Fallot's tetralogy
# C: Congenital mitral regurgitaion
# D: Congenital pulmonary stenosis
# answer: B
# exp: Finding reasoning paths:
#
# 1. Congenital heart disease -> Tetralogy of Fallot -> Cyanosis without cardiomegaly or congestive heart failure.
# 2. Congenital heart disease -> Tricuspid atresia -> Cyanosis with potential cardiomegaly or congestive heart failure.
# 3. Congenital heart disease -> Left ventricular noncompaction -> Congestive heart failure.
# 4. Congenital heart disease -> Long QT syndrome -> Congestive heart failure.
#
# Reasoning Process:
#
# 1. **Understanding the Question**: The question asks which congenital heart disease presents with cyanosis but without cardiomegaly or congestive heart failure. Cyanosis is a bluish discoloration of the skin due to low oxygen levels in the blood, often seen in congenital heart diseases with right-to-left shunts.
#
# 2. **Tetralogy of Fallot (TOF)**: This condition is characterized by four defects: ventricular septal defect (VSD), pulmonary stenosis, right ventricular hypertrophy, and an overriding aorta. The pulmonary stenosis causes a right-to-left shunt through the VSD, leading to cyanosis. The right ventricular hypertrophy is typically concentric, meaning the heart muscle thickens without dilating, which prevents cardiomegaly. The VSD allows blood to bypass the lungs, preventing congestive heart failure.
#
# 3. **Tricuspid Atresia**: This condition involves the absence of a tricuspid valve, leading to underdevelopment of the right ventricle. It often results in cyanosis due to mixing of oxygenated and deoxygenated blood. However, it can lead to cardiomegaly and congestive heart failure due to increased pressure and volume load on the left heart.
#
# 4. **Left Ventricular Noncompaction**: This is a rare cardiomyopathy that can lead to heart failure due to poor heart muscle function. It is not typically associated with cyanosis without heart failure.
#
# 5. **Long QT Syndrome**: This is a condition affecting the heart's electrical system, leading to arrhythmias. It is not typically associated with cyanosis or structural heart defects like cardiomegaly.
#
# Conclusion:
#
# Based on the reasoning, Tetralogy of Fallot is the congenital heart disease that presents with cyanosis without cardiomegaly or congestive heart failure. The combination of pulmonary stenosis and VSD in TOF allows for cyanosis without the heart enlargement or failure seen in other conditions.

# %%
import json

output_path = '/kaggle/working/UCSC_cardio.json'

with open(output_path, 'w', encoding='utf-8') as f:
    json.dump(cardio_questions, f, ensure_ascii=False, indent=2)

print(f"Exported {len(cardio_questions)} cardiovascular questions to {output_path}")
# Out:
# Exported 1225 cardiovascular questions to /kaggle/working/UCSC_cardio.json
